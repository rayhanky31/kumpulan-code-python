# %%
import nest_asyncio
nest_asyncio.apply()
import twint
import pandas as pd

# %%
c = twint.Config()
c.Search ="#TolakPenundaanPemilu" 
c.Limit = 100
c.Since = "2022-03-05"
c.Until = "2022-04-06"
c.Lang = "id"
c.Hide_output = True
c.Debug = True
c.Pandas = True

# %%
# %%time
try:
    print("Mulai Crawling")
    
    # konversi output ke format dataframe
    def twint_to_dataframe(columns):
        return twint.output.panda.Tweets_df[columns]
    
    # Mulai crawling
    twint.run.Search(c)
     
    # Save data crawling
    data = twint_to_dataframe(['date', 'username', 'tweet'])
    
    
except Exception as e:
    print(e)
print("Selesai")
print("=======")
# Out:
# Mulai Crawling
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# Selesai
# =======
# Wall time: 5.21 s

# %%
data
# Out:
#                    date         username  \
# 0   2022-04-06 05:41:06  Ajuansyah_putra
# 1   2022-04-06 04:53:02        wongkhito
# 2   2022-04-05 22:17:43   hadiprayitno82
# 3   2022-04-05 20:14:25        baharst28
# 4   2022-04-05 18:06:32   bersihkan_indo
# 5   2022-04-05 16:18:46    ki_cakrasurya
# 6   2022-04-05 13:33:17      yadiesa_mpf
# 7   2022-04-05 13:21:19        baharst28
# 8   2022-04-05 13:12:03    ki_cakrasurya
# 9   2022-04-05 10:35:54    choymarkochoy
# 10  2022-04-05 08:26:42    HariyantoStmm
# 11  2022-04-05 08:06:38       AniRukmini
# 12  2022-04-05 04:04:27  AzwarAn14582192
# 13  2022-04-04 21:55:15  AzwarAn14582192
# 14  2022-04-04 21:49:23  AzwarAn14582192
# 15  2022-04-04 21:46:59  AzwarAn14582192
# 16  2022-04-04 18:08:24         AMSiCare
# 17  2022-04-04 17:48:59  wawangu88797331
# 18  2022-04-04 17:48:48  KardusImajinasi
# 19  2022-04-04 17:46:39      UmaAyashii_
# 20  2022-04-04 17:45:44           Riez_1
# 21  2022-04-04 17:29:08      cebongsonto
# 22  2022-04-04 17:27:53     RtM3volusion
# 23  2022-04-04 17:19:24       rizkyalsyh
# 24  2022-04-04 14:51:32  Wahyudi48632434
# 25  2022-04-04 14:43:44    PKSDKIJakarta
# 26  2022-04-04 13:38:20       Pakamkalam
# 27  2022-04-04 13:00:10        ocehan_of
# 28  2022-04-04 12:58:54     juvelinealdi
# 29  2022-04-04 12:57:18  AzwarAn14582192
# 30  2022-04-04 12:49:39  lanyallacenter_
# 31  2022-04-04 12:48:36    HidayatNatari
# 32  2022-04-04 12:47:05     fai_bigheart
#
#                                                 tweet
# 0   Apa dia ngerti ? #PemiluSerentak2024 #TolakTeg...
# 1   #TolakTegasPenundaanPemilu  #tolakPenundaanPemilu
# 2   Suara Sumbang ancam Konstitusi, Marwah Desa di...
# 3   Banyak tong. Bahkan lbh baik. Siapa? Buka mata...
# 4   Jokowi klaim, usulan 3 periode dari masyarakat...
# 5   Istana ndableg, kita tetap demo.....  #tolakPe...
# 6   @hipohan Reformasi jilid II menanti.... #2024G...
# 7   Maju terus mhsiswa seluruh RI bersama rakyat !...
# 8   @NephiLaxmus Ormas dan dukungan abal2 masih ak...
# 9   Semakin dahsyat untuk mencapai nafsu kekuasaan...
# 10  Adik2 mahasiswa bergerak lagi ajak masyarakat ...
# 11              #tolakPenundaanPemilu  #Tolak3Periode
# 12  @geloraco Bila perlu gandeng jokowi untuk pula...
# 13  @muchlis_ar @dimerapi Malas liat muka jokowi  ...
# 14  @Micke03240524 Maju terus mahasiswa.. rakyat b...
# 15  Asal jangan jafi aktivis nasi bungkus saja mah...
# 16  Selamat berbuka puasa sob...,  Kalau gak ada 2...
# 17  Yang menerimanya aja gak jelas...masa orang yg...
# 18  @zarazettirazr Dikuasi Rakyat atau dikuasai Ch...
# 19  Semangat puasanya ya, h-27 lebaran nih. Mari t...
# 20  @CNNIndonesia Menteri segala urusan, semua elu...
# 21  #TolakTegasPenundaanPemilu  #tolakPenundaanPemilu
# 22   #TolakPenundaanPemilu2024  #tolakPenundaanPemilu
# 23  Apabila terjadi atau lolos di amandemen tentan...
# 24  @Lelaki_5uny1 Ikutan bang RH ahhh...!!😎😎😎 Yukk...
# 25  Ketika dilakukan perpanjangan masa jabatan pre...
# 26  Mau bangun fasilitas istana, tp rakyat disuruh...
# 27                              #tolakPenundaanPemilu
# 28  Lah iki pie maszee @bengkeldodo ? Brarti acara...
# 29  Fir'aun junior  #Tolak3Periode  #tolakPenundaa...
# 30  Temui LaNyalla, APDESI Tolak 3 Periode Jabatan...
# 31  Di negara lain presidennya itu manusia, kalau ...
# 32  #tolakPenundaanPemilu #Tolak3Periode  Coba yg ...

# %%
# Save data
data.to_csv('dataset_tundapemilu.csv', index=False)
